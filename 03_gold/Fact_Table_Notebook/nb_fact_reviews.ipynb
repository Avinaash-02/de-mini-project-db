# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_reviews = spark.read.table("de_mini_project.02_silver_schema.reviews")
display(df_reviews)

# %%
# %sql
   
CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.fact_reviews AS
SELECT
order_id,
review_score
FROM de_mini_project.02_silver_schema.reviews;

# %%
# %sql
SELECT * FROM de_mini_project.03_gold_schema.fact_reviews
