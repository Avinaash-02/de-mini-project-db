# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_payments = spark.read.table("de_mini_project.02_silver_schema.payments")
display(df_payments)

# %%
# %sql

CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.fact_payments AS
SELECT
  order_id,
  payment_type,
  payment_value,
  ROUND(total_payment_value,2) AS total_payment_value,
  payment_types_used
FROM de_mini_project.02_silver_schema.payments;

# %%
# %sql 
SELECT * FROM  de_mini_project.03_gold_schema.fact_payments
