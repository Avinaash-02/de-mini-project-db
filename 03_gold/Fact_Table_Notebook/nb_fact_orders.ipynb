# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_orders = spark.read.table("de_mini_project.02_silver_schema.orders")

# %%
display(df_orders)

# %%
# %sql
   
CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.fact_orders AS
SELECT
o.order_id,
o.customer_id,
CAST(o.order_purchase_timestamp AS DATE)AS order_date,
o.delivery_days,
o.is_late_delivery,
o.order_status
FROM de_mini_project.02_silver_schema.orders o;

# %%
# %sql 
SELECT * from de_mini_project.03_gold_schema.fact_orders;
