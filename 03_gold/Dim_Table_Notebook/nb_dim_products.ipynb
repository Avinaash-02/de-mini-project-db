# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_products = spark.read.table("de_mini_project.02_silver_schema.products")
display(df_products)

# %%
# %sql
CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.dim_products AS
SELECT DISTINCT
    product_id,
    product_category_name
FROM de_mini_project.02_silver_schema.products;
