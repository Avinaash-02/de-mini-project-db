# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_customers = spark.read.table("de_mini_project.02_silver_schema.customers")
display(df_customers)

# %%
# %sql
CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.dim_customers AS
SELECT DISTINCT
    customer_id,
    unique_id,
    zip_code_prefix
FROM de_mini_project.02_silver_schema.customers;

# %%
# %sql 
SELECT * FROM de_mini_project.03_gold_schema.dim_customers;
