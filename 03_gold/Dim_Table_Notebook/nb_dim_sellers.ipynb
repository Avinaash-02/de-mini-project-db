# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_sellers = spark.read.table("de_mini_project.02_silver_schema.sellers")
display(df_sellers)

# %%
# %sql
CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.dim_sellers AS
SELECT DISTINCT
    seller_id
FROM de_mini_project.02_silver_schema.sellers;

# %%
# %sql 
select * from de_mini_project.03_gold_schema.dim_sellers
