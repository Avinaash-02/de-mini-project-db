# %%
from pyspark.sql.functions import (col,year,month,dayofmonth,dayofweek,hour,minute,second,lower,trim,dayofmonth,quarter,weekofyear,date_format , monotonically_increasing_id)
df_geolocation = spark.read.table("de_mini_project.02_silver_schema.geolocation")
display(df_geolocation)

# %%
# %sql
CREATE OR REPLACE TABLE de_mini_project.03_gold_schema.dim_geolocation AS
SELECT DISTINCT
    zip_code_prefix,
    city,
    state
FROM de_mini_project.02_silver_schema.geolocation;
